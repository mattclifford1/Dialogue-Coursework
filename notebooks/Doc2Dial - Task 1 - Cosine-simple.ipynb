# %% [markdown]
# # Dialogue and Narrative Coursework - Subtask 1 - Cosine Similarity

# %%
from datasets import load_dataset, Dataset
import pandas as pd
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
import ast
new_val_data = pd.read_csv('doc2dial_rc_val.csv')
# Out:
# [nltk_data] Downloading package punkt to /home/matt/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
validate_full = True # set False to only validate on teh same contexts as training data

# %%
def train_predict_doc2vec(dataset, index):
  instance = dataset.iloc[index]
  docs = ast.literal_eval(instance['spans'])

  tokenized_docs = {}
  for i, d in docs.items():
      tokenized_docs[int(i)] = word_tokenize(d.lower())

  tagged_data = []
  for i, d in tokenized_docs.items():
    tagged_data.append(TaggedDocument(d, [i]))

  model = Doc2Vec(tagged_data, vector_size=80, window=5, min_count=1, workers=-1, epochs = 100)

  test_doc = instance['question'][5:]

  predictions = model.docvecs.most_similar(positive=[model.infer_vector(test_doc)], topn=30)
  # print(predictions)

  ids = []
  count = 0
  sum_score = 0
  pred = 0
  tol_zone = 5
  while True:

    id, score = predictions[pred]
    ids.append(id)
    count += 1
    sum_score += score

    pred += 1
    next_id, next_score = predictions[pred]

    possible_next_ids = list(range(id-tol_zone, id+tol_zone+1))
    # print(possible_next_ids)
    if next_id not in possible_next_ids:
      break

  sorted_ids = sorted(ids)
  text = ''
  for i in sorted_ids:
    text += docs.get(str(i), '')

  final_score = sum_score / count
  return {"id":instance["id"], "prediction_text":text, "no_answer_probability":1.0-final_score}

# %%
# get inds of contexts not in the training set
from word_counts import word_counter
import utils
def get_context_only():
    train_data1 = utils.load_own_rc_data(split="train")
    val_data1 = utils.load_own_rc_data(split="validation")

    counter = word_counter(train_data1)
    skip_inds = counter.no_context_availble(val_data1)

    good_data_inds = list(range(len(val_data1)))
    for ind in skip_inds:
        good_data_inds.remove(ind)
    return good_data_inds
good_data_inds = get_context_only()
    
# decide what data to validate
if validate_full:
    inds_to_val = range(len(new_val_data[:]))# all data use good_data_inds for context same as training
else:
    inds_to_val = good_data_inds

# %%
from tqdm import tqdm

preds = []
# new_val_data_slice = new_val_data[:100]
new_val_data_slice = new_val_data[:]

for i in tqdm(inds_to_val):
  preds.append(train_predict_doc2vec(new_val_data_slice, i))

preds
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3972/3972 [04:45<00:00, 13.89it/s]
# [{'id': 'dea7174409afbfe0af0ace21e7f318ae_1',
#   'prediction_text': 'Also , Because we all pay indirectly for crashes involving uninsured motorists , ',
#   'no_answer_probability': 0.8130782395601273},
#  {'id': 'dea7174409afbfe0af0ace21e7f318ae_3',
#   'prediction_text': 'you will miss a suspension order and may be charged with operating an unregistered vehicle and/or aggravated unlicensed operation, both misdemeanors. ',
#   'no_answer_probability': 0.7683570832014084},
#  {'id': 'dea7174409afbfe0af0ace21e7f318ae_5',
#   'prediction_text': 'About ten percent of customers visiting a DMV office do not bring what they need to complete their transaction, and have to come back a second time to finish their business. ',
#   'no_answer_probability': 0.777058482170105},
#  {'id': 'dea7174409afbfe0af0ace21e7f318ae_7',
#   'prediction_text': 'A license suspension or revocation here could mean that your new home state will not issue you a license there. ',
#   'no_answer_probability': 0.690319836139679},
#  {'id': 'dea7174409afbfe0af0ace21e7f318ae_9',
#   'prediction_text': 'turning in your plates is important to avoid an insurance lapse. ',
#   'no_answer_probability': 0.7362178564071655},
#  {'id': 'dea7174409afbfe0af0ace21e7f318ae_12',
#   'prediction_text': 'That is the case for the address associated with your license, as well as all the addresses associated with each registered vehicle, which may differ. If you fail to keep your address current , ',
#   'no_answer_probability': 0.7985050082206726},
#  {'id': 'dea7174409afbfe0af0ace21e7f318ae_14',
#   'prediction_text': 'Learn more about About the NYS Driver Point System [4] and how to Pay Driver Responsibility Assessment [5 ] ',
#   'no_answer_probability': 0.819160133600235},
#  {'id': 'dea7174409afbfe0af0ace21e7f318ae_16',
#   'prediction_text': 'The $300 DRA fee can be paid in $100 annual installments over three years. ',
#   'no_answer_probability': 0.7415494322776794},
#  {'id': '83d090a234b905fa4f0cb8ed8f0b5535_1',
#   'prediction_text': '\n\n5. Not Bringing Proper Documentation to DMV Office \n',
#   'no_answer_probability': 0.6955955624580383},
#  {'id': '83d090a234b905fa4f0cb8ed8f0b5535_5',
#   'prediction_text': 'Learn more about About the NYS Driver Point System [4] and how to Pay Driver Responsibility Assessment [5 ] ',
#   'no_answer_probability': 0.6962441205978394},
#  {'id': '83d090a234b905fa4f0cb8ed8f0b5535_7',
#   'prediction_text': 'Our award - winning website is recognized as one of the best in the nation. ',
#   'no_answer_probability': 0.6147590577602386},
#  {'id': '83d090a234b905fa4f0cb8ed8f0b5535_9',
#   'prediction_text': 'Learn more about how to change the address on your license and registrations [1 ] States communicate with each other , ',
#   'no_answer_probability': 0.7902125418186188},
#  {'id': '83d090a234b905fa4f0cb8ed8f0b5535_11',
#   'prediction_text': 'and we will suspend your registration and license. ',
#   'no_answer_probability': 0.7401459217071533},
#  {'id': '83d090a234b905fa4f0cb8ed8f0b5535_13',
#   'prediction_text': 'you must report a change of address to DMV within ten days of moving. ',
#   'no_answer_probability': 0.7573933005332947},
#  {'id': '9f5633139a815b123df20367a37e9fc4_1',
#   'prediction_text': 'We do not disclose the DIAL - IN account numbers of the account holder that performed the search. ',
#   'no_answer_probability': 0.7727094739675522},
#  {'id': '9f5633139a815b123df20367a37e9fc4_4',
#   'prediction_text': 'the time, date and search criteria used to search for the records. ',
#   'no_answer_probability': 0.8031403720378876},
#  {'id': '9f5633139a815b123df20367a37e9fc4_6',
#   'prediction_text': 'We are upgrading our security protocols to better protect your data. ',
#   'no_answer_probability': 0.6424680948257446},
#  {'id': '9f5633139a815b123df20367a37e9fc4_8',
#   'prediction_text': 'Your first deposit must be enough to pay for two months of searches. ',
#   'no_answer_probability': 0.7227541208267212},
#  {'id': '9f5633139a815b123df20367a37e9fc4_10',
#   'prediction_text': 'DMV may ask you about a DIAL - IN search you performed. ',
#   'no_answer_probability': 0.7327806949615479},
#  {'id': '9f5633139a815b123df20367a37e9fc4_12',
#   'prediction_text': 'contact us immediately. ',
#   'no_answer_probability': 0.7449183762073517},
#  {'id': 'be588fec30ffd8149a53615c46970798_1',
#   'prediction_text': 'we will create an account for you. ',
#   'no_answer_probability': 0.7730407267808914},
#  {'id': 'be588fec30ffd8149a53615c46970798_4',
#   'prediction_text': 'You can complete an inquiry at any time if you send us the requested acceptable business records. ',
#   'no_answer_probability': 0.7272748947143555},
#  {'id': 'be588fec30ffd8149a53615c46970798_6',
#   'prediction_text': 'If you performed the search on behalf of a client , ',
#   'no_answer_probability': 0.8369157761335373},
#  {'id': 'be588fec30ffd8149a53615c46970798_8',
#   'prediction_text': 'If none of the known users performed the search , Records of searches are public records. ',
#   'no_answer_probability': 0.7287579923868179},
#  {'id': 'be588fec30ffd8149a53615c46970798_10',
#   'prediction_text': 'your deposit is added to your new account balance. ',
#   'no_answer_probability': 0.775091826915741},
#  {'id': 'be588fec30ffd8149a53615c46970798_12',
#   'prediction_text': 'If a motorist asks the DMV if his records were searched , ',
#   'no_answer_probability': 0.707229495048523},
#  {'id': '27792b3995d3965961055a569a5aede1_1',
#   'prediction_text': 'Keep the other paper card with the vehicle as your proof of insurance. \n\nDoes the name on my vehicle registration application and Insurance Identification Card need to be the same? \n',
#   'no_answer_probability': 0.7128347903490067},
#  {'id': '27792b3995d3965961055a569a5aede1_4',
#   'prediction_text': '\n\nDo I need insurance? \n',
#   'no_answer_probability': 0.7011560201644897},
#  {'id': '27792b3995d3965961055a569a5aede1_6',
#   'prediction_text': 'When you get insurance , give you two original NY State Insurance ID Cards see a sample [3] or provide you with access to your digital electronic NY State Insurance ID Card 3 ',
#   'no_answer_probability': 0.7605397328734398},
#  {'id': '27792b3995d3965961055a569a5aede1_8',
#   'prediction_text': 'However , ',
#   'no_answer_probability': 0.7477751970291138},
#  {'id': '27792b3995d3965961055a569a5aede1_10',
#   'prediction_text': 'All Owned & Non - Owned Comprehensive Auto Liability Policy AON ',
#   'no_answer_probability': 0.7141861319541931},
#  {'id': '27792b3995d3965961055a569a5aede1_12',
#   'prediction_text': 'Your liability insurance coverage must ',
#   'no_answer_probability': 0.7936991900205612},
#  {'id': '10db331606ecf90e67a808d8fb7e411a_1',
#   'prediction_text': 'If you do not maintain the coverage , ',
#   'no_answer_probability': 0.7489515542984009},
#  {'id': '10db331606ecf90e67a808d8fb7e411a_5',
#   'prediction_text': 'When you get insurance , ',
#   'no_answer_probability': 0.7814075648784637},
#  {'id': '10db331606ecf90e67a808d8fb7e411a_7',
#   'prediction_text': 'Both the primary registrant first name listed on the registration and the co - registrant must sign the Vehicle Registration / Title Application PDF [2] MV-82 and provide their proofs of identity and date of birth. ',
#   'no_answer_probability': 0.7591981142759323},
#  {'id': '10db331606ecf90e67a808d8fb7e411a_9',
#   'prediction_text': '$ 50,000 for bodily injury and $100,000 for death for two or more people in an accident ',
#   'no_answer_probability': 0.7695830464363098},
#  {'id': '10db331606ecf90e67a808d8fb7e411a_11',
#   'prediction_text': '\n\nDo I need insurance? \n',
#   'no_answer_probability': 0.7709192633628845},
#  {'id': 'c76af36d54451ddd09676713fd889065_1',
#   'prediction_text': 'the sales tax 1 The fees listed in the chart are for commercial vehicles that weigh less than 18,000 lbs. ',
#   'no_answer_probability': 0.7731534689664841},
#  {'id': 'c76af36d54451ddd09676713fd889065_5',
#   'prediction_text': 'the sales tax 1 \n\nRegistration fee chart for commercial vehicles \n',
#   'no_answer_probability': 0.8012364506721497},
#  {'id': 'c76af36d54451ddd09676713fd889065_8',
#   'prediction_text': 'If this is the original registration of your vehicle , the sales tax 1 ',
#   'no_answer_probability': 0.7250470221042633},
#  {'id': 'c76af36d54451ddd09676713fd889065_10',
#   'prediction_text': 'This tax applies to Medallion taxis with a plate number configuration of " TnnnnnC " or " TnnnnnnC ". ',
#   'no_answer_probability': 0.8001963794231415},
#  {'id': 'c76af36d54451ddd09676713fd889065_12',
#   'prediction_text': 'The classes include Agricultural AGR, Ambulance AMB, Farm FAR, Historical HIS, House Trailer HOU, Semi Trailer SEM, Special Purpose Commercial SPC, and Trailer TRL. ',
#   'no_answer_probability': 0.8122823238372803},
#  {'id': '47d8822063e3d1b654b289f45d412789_1',
#   'prediction_text': 'the fees for your vehicle plates $25.00 ',
#   'no_answer_probability': 0.7760811001062393},
#  {'id': '47d8822063e3d1b654b289f45d412789_4',
#   'prediction_text': 'Bus (OMR) Note : ',
#   'no_answer_probability': 0.7958207651972771},
#  {'id': '47d8822063e3d1b654b289f45d412789_6',
#   'prediction_text': 'This tax applies to Medallion taxis with a plate number configuration of " TnnnnnC " or " TnnnnnnC ". This tax does not include Medallion taxis with plate number configurations: " TnnnnnT ", " TnnnnnnT ", " nana ", " nanna ", " nnnSBVa " and " nnnSBVan ". ',
#   'no_answer_probability': 0.7704757824540138},
#  {'id': '47d8822063e3d1b654b289f45d412789_8',
#   'prediction_text': 'Residents of New York City and several counties in New York must pay a vehicle use tax when they register a commercial vehicle or renew a commercial vehicle registration. If you reside outside New York City and you are exempt from the vehicle use tax in the county where you reside or have a business , ',
#   'no_answer_probability': 0.7536068558692932},
#  {'id': '47d8822063e3d1b654b289f45d412789_10',
#   'prediction_text': 'All registrants for " TC " vehicle plates must pay the vehicle use tax. \n\nCounty use tax chart for counties outside of New York City \n',
#   'no_answer_probability': 0.8035100847482681},
#  {'id': '47d8822063e3d1b654b289f45d412789_12',
#   'prediction_text': 'If you reside outside New York City and you are exempt from the vehicle use tax in the county where you reside or have a business , ',
#   'no_answer_probability': 0.8093821853399277},
#  {'id': '47d8822063e3d1b654b289f45d412789_14',
#   'prediction_text': 'Several registration classes are exempt from the additional fee. ',
#   'no_answer_probability': 0.7204194366931915},
#  {'id': 'c7d24046942242f386a3bc811f696284_1',
#   'prediction_text': "Before you end the vehicle's liability insurance coverage. ",
#   'no_answer_probability': 0.7439505457878113},
#  {'id': 'c7d24046942242f386a3bc811f696284_3',
#   'prediction_text': 'Do not give your plates to another person unless that person will surrender the plates for you. ',
#   'no_answer_probability': 0.8085108399391174},
#  {'id': 'c7d24046942242f386a3bc811f696284_5',
#   'prediction_text': 'It s not necessary to surrender motorcycle plates , ',
#   'no_answer_probability': 0.7640091478824615},
#  {'id': 'c7d24046942242f386a3bc811f696284_7',
#   'prediction_text': 'Step 1 : ',
#   'no_answer_probability': 0.6843806803226471},
#  {'id': 'c7d24046942242f386a3bc811f696284_9',
#   'prediction_text': 'A motorcycle must have liability insurance to be operated. ',
#   'no_answer_probability': 0.7920081466436386},
#  {'id': 'c7d24046942242f386a3bc811f696284_11',
#   'prediction_text': 'Normally a trailer does not need liability insurance. ',
#   'no_answer_probability': 0.7788374423980713},
#  {'id': 'c7d24046942242f386a3bc811f696284_13',
#   'prediction_text': 'Remove plates and stickers ',
#   'no_answer_probability': 0.7227463722229004},
#  {'id': 'ac3c7b5541da7893b6f28c565e14be95_1',
#   'prediction_text': 'Trailers : ',
#   'no_answer_probability': 0.7199486792087555},
#  {'id': 'ac3c7b5541da7893b6f28c565e14be95_4',
#   'prediction_text': '\n\nRefunds \n',
#   'no_answer_probability': 0.6770223081111908},
#  {'id': 'ac3c7b5541da7893b6f28c565e14be95_6',
#   'prediction_text': 'Motorcycles : The DMV will not suspend your driver license or registration if you fail to surrender the plate. ',
#   'no_answer_probability': 0.7119856923818588},
#  {'id': 'ac3c7b5541da7893b6f28c565e14be95_9',
#   'prediction_text': 'If another person surrenders your plates for you , ',
#   'no_answer_probability': 0.6738992035388947},
#  {'id': 'ac3c7b5541da7893b6f28c565e14be95_11',
#   'prediction_text': '\n\nMotorcycle and trailer plates \n',
#   'no_answer_probability': 0.779855266213417},
#  {'id': '3bee48d7fc015432db1eebf78dc8bb52_1',
#   'prediction_text': 'are under age 62 , ',
#   'no_answer_probability': 0.7455977499485016},
#  {'id': '3bee48d7fc015432db1eebf78dc8bb52_3',
#   'prediction_text': 'follow these steps : ',
#   'no_answer_probability': 0.7875788360834122},
#  {'id': '3bee48d7fc015432db1eebf78dc8bb52_5',
#   'prediction_text': "You can't get a reduced or no fee renewal if you renew online. ",
#   'no_answer_probability': 0.7319474518299103},
#  {'id': '3bee48d7fc015432db1eebf78dc8bb52_7',
#   'prediction_text': 'If you did not receive a renewal notice , ',
#   'no_answer_probability': 0.6979479193687439},
#  {'id': '3bee48d7fc015432db1eebf78dc8bb52_9',
#   'prediction_text': 'that you are eligible for SSI benefits ',
#   'no_answer_probability': 0.7023749947547913},
#  {'id': '50f6b766c50164e444b90ef83528ae56_1',
#   'prediction_text': 'you must go to a DMV office with your updated paperwork from the United States Department of Homeland Security DHS. ',
#   'no_answer_probability': 0.7512151002883911},
#  {'id': '50f6b766c50164e444b90ef83528ae56_3',
#   'prediction_text': 'Report of Confidential Social Security Information SSA-2258 If you are age 62 or older and receive Supplemental Security Income SSI , ',
#   'no_answer_probability': 0.7348561808466911},
#  {'id': '50f6b766c50164e444b90ef83528ae56_5',
#   'prediction_text': 'If you are age 62 or older and receive Supplemental Security Income SSI , ',
#   'no_answer_probability': 0.661688357591629},
#  {'id': '50f6b766c50164e444b90ef83528ae56_7',
#   'prediction_text': 'you have a Standard document. If you want to renew in an office and keep your Standard document type , ',
#   'no_answer_probability': 0.6241380274295807},
#  {'id': '50f6b766c50164e444b90ef83528ae56_9',
#   'prediction_text': "Newly issued Standard documents show :' NOT FOR FEDERAL PURPOSES'. Step 1 : ",
#   'no_answer_probability': 0.7105283141136169},
#  {'id': 'ce79a72591524ec770ce21f99f92ac7b_1',
#   'prediction_text': '\n\nIs it possible to receive a refund of the first-year of my registration fee? \n',
#   'no_answer_probability': 0.7445199489593506},
#  {'id': 'ce79a72591524ec770ce21f99f92ac7b_3',
#   'prediction_text': 'You have a maximum of 60 days after the date the registration was issued to apply for the 1st year of the registration fee. ',
#   'no_answer_probability': 0.6439988017082214},
#  {'id': 'ce79a72591524ec770ce21f99f92ac7b_5',
#   'prediction_text': 'that prove the name has changed ',
#   'no_answer_probability': 0.6640400886535645},
#  {'id': 'ce79a72591524ec770ce21f99f92ac7b_7',
#   'prediction_text': '\n\nTransfer credit \n',
#   'no_answer_probability': 0.726588249206543},
#  {'id': 'ce79a72591524ec770ce21f99f92ac7b_9',
#   'prediction_text': 'You cannot use it for a registration renewal. Here is an example to show how your refund amount is determined. ',
#   'no_answer_probability': 0.7750503048300743},
#  {'id': 'ce79a72591524ec770ce21f99f92ac7b_11',
#   'prediction_text': "call the DMV Revenue Accounting Unit at 518 - 474 - 0902 to request a' Next of Kin' form. ",
#   'no_answer_probability': 0.7941787838935852},
#  {'id': 'ce79a72591524ec770ce21f99f92ac7b_13',
#   'prediction_text': 'You paid $137.50 to register your vehicle for two years. ',
#   'no_answer_probability': 0.803772896528244},
#  {'id': '0982c8b2c4ad57fbd3c6742faee1b15f_1',
#   'prediction_text': 'completed and signed Request for Refund [1] MV-215, with " deceased " written on the form ',
#   'no_answer_probability': 0.7798315137624741},
#  {'id': '0982c8b2c4ad57fbd3c6742faee1b15f_3',
#   'prediction_text': 'For example , ',
#   'no_answer_probability': 0.7325686514377594},
#  {'id': '0982c8b2c4ad57fbd3c6742faee1b15f_5',
#   'prediction_text': 'There is no refund of other fees or taxes. ',
#   'no_answer_probability': 0.7712607830762863},
#  {'id': '0982c8b2c4ad57fbd3c6742faee1b15f_7',
#   'prediction_text': 'have the executor of the deceased s will send these items to the address listed on the Request for Refund MV-215 ',
#   'no_answer_probability': 0.6833707988262177},
#  {'id': '0982c8b2c4ad57fbd3c6742faee1b15f_9',
#   'prediction_text': 'your new registration will expire the same day as your old registration. ',
#   'no_answer_probability': 0.7650378048419952},
#  {'id': '0982c8b2c4ad57fbd3c6742faee1b15f_11',
#   'prediction_text': 'The amount you paid included $62.50 for the two years of the registration $31.25 per year, $50.00 for the title certificate and $25.00 for the vehicle plates. ',
#   'no_answer_probability': 0.7566779851913452},
#  {'id': '0982c8b2c4ad57fbd3c6742faee1b15f_13',
#   'prediction_text': 'you must surrender the vehicle plates and the unused registration sticker and stub at a DMV office and request a 2-year refund. ',
#   'no_answer_probability': 0.6922720074653625},
#  {'id': '9b2d9d43375491f9bb014f0f39673a16_1',
#   'prediction_text': 'stop your vehicle before it reaches an intersecting street. ',
#   'no_answer_probability': 0.7013653516769409},
#  {'id': '9b2d9d43375491f9bb014f0f39673a16_3',
#   'prediction_text': 'Clutch / Gears : ',
#   'no_answer_probability': 0.6928542256355286},
#  {'id': '9b2d9d43375491f9bb014f0f39673a16_5',
#   'prediction_text': 'look online or in your telephone directory for Driving Instruction. ',
#   'no_answer_probability': 0.7156949043273926},
#  {'id': '9b2d9d43375491f9bb014f0f39673a16_7',
#   'prediction_text': 'if you are under age 18 , ',
#   'no_answer_probability': 0.7700875252485275},
#  {'id': '9b2d9d43375491f9bb014f0f39673a16_9',
#   'prediction_text': 'contact the school that issued it to obtain a replacement. ',
#   'no_answer_probability': 0.7532185614109039},
#  {'id': '9b2d9d43375491f9bb014f0f39673a16_11',
#   'prediction_text': 'Be sure to increase your following distance in poor weather or visibility. ',
#   'no_answer_probability': 0.6704068183898926},
#  {'id': '9b2d9d43375491f9bb014f0f39673a16_13',
#   'prediction_text': 'The course covers many important topics, including ',
#   'no_answer_probability': 0.7301632165908813},
#  {'id': '9b2d9d43375491f9bb014f0f39673a16_15',
#   'prediction_text': 'Traffic signs, signals and markings : ',
#   'no_answer_probability': 0.792343944311142},
#  {'id': '93aadf11feb6bb1fc54a55a3eecb5cf2_1',
#   'prediction_text': 'Steer smoothly whether you are driving straight ahead, turning or backing up. ',
#   'no_answer_probability': 0.727109432220459},
#  {'id': '93aadf11feb6bb1fc54a55a3eecb5cf2_3',
#   'prediction_text': 'before you take your road test you must ',
#   'no_answer_probability': 0.7504305392503738},
#  {'id': '93aadf11feb6bb1fc54a55a3eecb5cf2_5',
#   'prediction_text': 'and you do not need a Pre - licensing Course Certificate. ',
#   'no_answer_probability': 0.7751560211181641},
#  {'id': '93aadf11feb6bb1fc54a55a3eecb5cf2_7',
#   'prediction_text': 'Observation : ',
#   'no_answer_probability': 0.7565289735794067},
#  {'id': '93aadf11feb6bb1fc54a55a3eecb5cf2_9',
#   'prediction_text': 'other drugs and driving ',
#   'no_answer_probability': 0.7466971576213837},
#  {'id': '93aadf11feb6bb1fc54a55a3eecb5cf2_11',
#   'prediction_text': 'Your certificate must be valid on the date that you make your Road Test appointment, but can be expired on the date you take your road test. ',
#   'no_answer_probability': 0.7351123094558716},
#  {'id': '93aadf11feb6bb1fc54a55a3eecb5cf2_13',
#   'prediction_text': 'Start braking well before your stopping position to avoid abrupt stops. ',
#   'no_answer_probability': 0.7650182247161865},
#  {'id': '93aadf11feb6bb1fc54a55a3eecb5cf2_15',
#   'prediction_text': 'Steer smoothly whether you are driving straight ahead, turning or backing up. ',
#   'no_answer_probability': 0.7323574125766754},
#  {'id': '3a410477dbe131c029e2d94f2f893cf7_1',
#   'prediction_text': 'If you request a replacement driver license 41 days or more before your 21st birthday , ',
#   'no_answer_probability': 0.7026717066764832},
#  {'id': '3a410477dbe131c029e2d94f2f893cf7_3',
#   'prediction_text': 'Visa Debit Card without personal identification number PIN ',
#   'no_answer_probability': 0.6276326179504395},
#  {'id': '3a410477dbe131c029e2d94f2f893cf7_5',
#   'prediction_text': 'you can replace by mail. ',
#   'no_answer_probability': 0.7185381352901459},
#  {'id': '3a410477dbe131c029e2d94f2f893cf7_7',
#   'prediction_text': 'Don t write the alternate address on form MV-44. ',
#   'no_answer_probability': 0.7410264611244202},
#  {'id': '3a410477dbe131c029e2d94f2f893cf7_9',
#   'prediction_text': 'you can replace by mail. ',
#   'no_answer_probability': 0.7307799458503723},
#  {'id': '3a410477dbe131c029e2d94f2f893cf7_11',
#   'prediction_text': 'Complete this guide to make sure you have the proofs of identification you need before you come to DMV. ',
#   'no_answer_probability': 0.6717913448810577},
#  {'id': '3a410477dbe131c029e2d94f2f893cf7_13',
#   'prediction_text': 'it will say UNDER 21. ',
#   'no_answer_probability': 0.6900655627250671},
#  {'id': '3a410477dbe131c029e2d94f2f893cf7_15',
#   'prediction_text': 'If you already have an Enhanced or REAL ID, or you want to keep your Standard , \n\nSend \n',
#   'no_answer_probability': 0.7074401825666428},
#  {'id': '3a8b0307c3889e2c51b3ea3a6954bce7_1',
#   'prediction_text': 'You do not need an eye exam when you replace your document. ',
#   'no_answer_probability': 0.7383049428462982},
#  {'id': '3a8b0307c3889e2c51b3ea3a6954bce7_4',
#   'prediction_text': 'When you order by mail or at a DMV office [8], ',
#   'no_answer_probability': 0.7303298711776733},
#  {'id': '3a8b0307c3889e2c51b3ea3a6954bce7_6',
#   'prediction_text': '\n\nAddress and mailing information \n',
#   'no_answer_probability': 0.6743587255477905},
#  {'id': '3a8b0307c3889e2c51b3ea3a6954bce7_8',
#   'prediction_text': 'The mailing address you write on form MV-44 must be the address that is listed on your photo document and your DMV record. ',
#   'no_answer_probability': 0.7115879654884338},
#  {'id': '3a8b0307c3889e2c51b3ea3a6954bce7_10',
#   'prediction_text': 'VISA Card you must apply at a DMV office and show form MV-78B completed by the police. ',
#   'no_answer_probability': 0.7044363021850586},
#  {'id': '3a8b0307c3889e2c51b3ea3a6954bce7_12',
#   'prediction_text': "Don't delay! Replace online [4 ] ",
#   'no_answer_probability': 0.6821788400411606},
#  {'id': '3a8b0307c3889e2c51b3ea3a6954bce7_14',
#   'prediction_text': 'Replace online [4 ] ',
#   'no_answer_probability': 0.7064192891120911},
#  {'id': 'e7545e6f53bbe7d12b6846061f8dd6ed_1',
#   'prediction_text': 'Yes , ',
#   'no_answer_probability': 0.6543718576431274},
#  {'id': 'e7545e6f53bbe7d12b6846061f8dd6ed_3',
#   'prediction_text': 'To register to receive these reminders , ',
#   'no_answer_probability': 0.6844994425773621},
#  {'id': 'e7545e6f53bbe7d12b6846061f8dd6ed_5',
#   'prediction_text': 'then the NI driving type will allow for the broadest commercial operation capability with no license restrictions applied. ',
#   'no_answer_probability': 0.7060995399951935},
#  {'id': 'e7545e6f53bbe7d12b6846061f8dd6ed_7',
#   'prediction_text': '\n\n2. What are the self-certification driving types? \n',
#   'no_answer_probability': 0.7240012884140015},
#  {'id': 'e7545e6f53bbe7d12b6846061f8dd6ed_9',
#   'prediction_text': 'CDL holders that certify to EA can only operate a commercial motor vehicle within New York State, and cannot deliver cargo coming from, or being delivered to, another state or foreign country. ',
#   'no_answer_probability': 0.7109484076499939},
#  {'id': 'e7545e6f53bbe7d12b6846061f8dd6ed_11',
#   'prediction_text': 'When we receive your new updated medical certificate , you will need to visit a local DMV office to upgrade your license back to a CDL. ',
#   'no_answer_probability': 0.746181882917881},
#  {'id': 'e7545e6f53bbe7d12b6846061f8dd6ed_13',
#   'prediction_text': 'A transaction fee will apply. ',
#   'no_answer_probability': 0.7668314278125763},
#  {'id': '6384f618136a1d9474b30f6e9ce006db_1',
#   'prediction_text': 'New York State Department of Motor VehiclesBus Driver Unit Customer Service Unit 6 Empire State Plaza , ',
#   'no_answer_probability': 0.7400729358196259},
#  {'id': '6384f618136a1d9474b30f6e9ce006db_5',
#   'prediction_text': 'you will be immediately certified to provide escort services for over - dimensional loads. You must have the certificate in your possession when providing escort services. ',
#   'no_answer_probability': 0.7069129198789597},
#  {'id': '6384f618136a1d9474b30f6e9ce006db_7',
#   'prediction_text': 'No , You must carry the MV-64 card with your driver license when you drive an escort vehicle in NY State. Out of state drivers who do not have current New York State driving privileges are not eligible for escort certification ',
#   'no_answer_probability': 0.7703320483366648},
#  {'id': '6384f618136a1d9474b30f6e9ce006db_9',
#   'prediction_text': '',
#   'no_answer_probability': 0.5974888801574707},
#  {'id': '6384f618136a1d9474b30f6e9ce006db_11',
#   'prediction_text': 'have a valid New York State driver license or valid license in the state or jurisdiction in which you are a resident 2 ',
#   'no_answer_probability': 0.7050564289093018},
#  {'id': 'b906f692960dfc54e5fe197311ce3694_1',
#   'prediction_text': 'If your vehicle is recovered before you transfer the " insurance transfer only " title to your insurance company , Then send the title to the Title Bureau along with a letter explaining that your vehicle was recovered, and DMV will issue a regular title. ',
#   'no_answer_probability': 0.77249875664711},
#  {'id': 'b906f692960dfc54e5fe197311ce3694_3',
#   'prediction_text': 'The MV-907A is an ownership document that can be transferred to your insurance company. ',
#   'no_answer_probability': 0.7920114994049072},
#  {'id': 'b906f692960dfc54e5fe197311ce3694_5',
#   'prediction_text': 'bring the plates and your copy of the MV-78B to a DMV office to surrender them and apply for new plates and to re - instate your registration. ',
#   'no_answer_probability': 0.672083854675293},
#  {'id': 'b906f692960dfc54e5fe197311ce3694_7',
#   'prediction_text': 'you must apply for a duplicate title. See Replace a Title Certificate [2] for more information. make sure the police have cancelled the stolen vehicle alarm. ',
#   'no_answer_probability': 0.7786543369293213},
#  {'id': 'b906f692960dfc54e5fe197311ce3694_9',
#   'prediction_text': 'If the vehicle and plates are recovered before you file form MV-78B, and the stolen vehicle alarm has been cancelled , ',
#   'no_answer_probability': 0.7826771587133408},
#  {'id': 'b906f692960dfc54e5fe197311ce3694_11',
#   'prediction_text': 'If the vehicle and plates are recovered before you file form MV-78B, and the stolen vehicle alarm has been cancelled , ',
#   'no_answer_probability': 0.7571590542793274},
#  {'id': 'b906f692960dfc54e5fe197311ce3694_13',
#   'prediction_text': 'If the vehicle is damaged or totaled , ',
#   'no_answer_probability': 0.7967005968093872},
#  {'id': '9cd8e929d260d5814b03867fef5f2711_1',
#   'prediction_text': 'you may have to transfer ownership to your insurance company using your title certificate. If you have lost your title certificate , ',
#   'no_answer_probability': 0.7117385417222977},
#  {'id': '9cd8e929d260d5814b03867fef5f2711_3',
#   'prediction_text': 'If the vehicle was stolen before you were able to apply for registration and title in your name , ',
#   'no_answer_probability': 0.7584725916385651},
#  {'id': '9cd8e929d260d5814b03867fef5f2711_5',
#   'prediction_text': 'If your vehicle is not recovered , ',
#   'no_answer_probability': 0.7068269550800323},
#  {'id': '9cd8e929d260d5814b03867fef5f2711_7',
#   'prediction_text': 'see Report or Replace Lost or Stolen Plates [1]. ',
#   'no_answer_probability': 0.7262969613075256},
#  {'id': '9cd8e929d260d5814b03867fef5f2711_9',
#   'prediction_text': 'For further information , ',
#   'no_answer_probability': 0.6679770350456238},
#  {'id': '9cd8e929d260d5814b03867fef5f2711_11',
#   'prediction_text': 'If you have lost your title certificate , A duplicate title issued when a vehicle is stolen is marked to show the vehicle is stolen and that the duplicate title is valid for insurance transfer only. If your vehicle is recovered before you transfer the " insurance transfer only " title to your insurance company , ',
#   'no_answer_probability': 0.7733037620782852},
#  {'id': '9cd8e929d260d5814b03867fef5f2711_13',
#   'prediction_text': 'See Apply for a Title Certificate Only [4] at our website. ',
#   'no_answer_probability': 0.7956083863973618},
#  {'id': '9cd8e929d260d5814b03867fef5f2711_15',
#   'prediction_text': 'The MV-907A is an ownership document that can be transferred to your insurance company. ',
#   'no_answer_probability': 0.813395231962204},
#  {'id': 'eef99bfcea6b747ff0ef6adc5f050a06_1',
#   'prediction_text': '\n\nTopic: \n',
#   'no_answer_probability': 0.63126140832901},
#  {'id': 'eef99bfcea6b747ff0ef6adc5f050a06_3',
#   'prediction_text': 'Learner permit restrictions apply to all permit classes. ',
#   'no_answer_probability': 0.8307936787605286},
#  {'id': 'eef99bfcea6b747ff0ef6adc5f050a06_5',
#   'prediction_text': '\n\nWhat is considered a limited use motorcycle (aka moped )? \n',
#   'no_answer_probability': 0.6336861848831177},
#  {'id': 'eef99bfcea6b747ff0ef6adc5f050a06_7',
#   'prediction_text': '\n\nTopic: \n',
#   'no_answer_probability': 0.7621668577194214},
#  {'id': 'eef99bfcea6b747ff0ef6adc5f050a06_9',
#   'prediction_text': 'Registration [11 ] ',
#   'no_answer_probability': 0.684289813041687},
#  {'id': 'eef99bfcea6b747ff0ef6adc5f050a06_11',
#   'prediction_text': '\n\nWhat do I need to bring to the DMV? \n',
#   'no_answer_probability': 0.749319463968277},
#  {'id': 'eef99bfcea6b747ff0ef6adc5f050a06_13',
#   'prediction_text': '\n\nTopic: \n',
#   'no_answer_probability': 0.765982985496521},
#  {'id': 'eef99bfcea6b747ff0ef6adc5f050a06_15',
#   'prediction_text': "The class is determined by the range of the vehicle's top speed. ",
#   'no_answer_probability': 0.7683783769607544},
#  {'id': '630481c93cb85b8daf98b15e61dc1a05_1',
#   'prediction_text': 'a driver age 21 or older ',
#   'no_answer_probability': 0.7110581994056702},
#  {'id': '630481c93cb85b8daf98b15e61dc1a05_3',
#   'prediction_text': 'Usually, the earliest date is within three to five weeks , ',
#   'no_answer_probability': 0.6895036399364471},
#  {'id': '630481c93cb85b8daf98b15e61dc1a05_5',
#   'prediction_text': 'Discover Card /Novus ',
#   'no_answer_probability': 0.6869875192642212},
#  {'id': '630481c93cb85b8daf98b15e61dc1a05_7',
#   'prediction_text': 'who has a license valid to operate the test vehicle ',
#   'no_answer_probability': 0.712857574224472},
#  {'id': '630481c93cb85b8daf98b15e61dc1a05_9',
#   'prediction_text': 'if you are under 18, a Certification of Supervised Driving PDF [7] MV-262 completed by your parent or guardian - ',
#   'no_answer_probability': 0.6880090236663818},
#  {'id': '630481c93cb85b8daf98b15e61dc1a05_11',
#   'prediction_text': 'you will receive your photo driver license in the mail, in about 2 weeks ',
#   'no_answer_probability': 0.7228429019451141},
#  {'id': '630481c93cb85b8daf98b15e61dc1a05_13',
#   'prediction_text': 'Keep the interim license with your photo learner permit ',
#   'no_answer_probability': 0.6835905909538269},
#  {'id': '630481c93cb85b8daf98b15e61dc1a05_15',
#   'prediction_text': '\n\nyes or no survey: \n',
#   'no_answer_probability': 0.7015946507453918},
#  {'id': 'cd0cfb77675741b68ed4086445228e92_1',
#   'prediction_text': 'See Get a learner permit [10]. ',
#   'no_answer_probability': 0.763983428478241},
#  {'id': 'cd0cfb77675741b68ed4086445228e92_3',
#   'prediction_text': '\n\nTopic: \n\n\nshow mydmv button in megamenu: \n',
#   'no_answer_probability': 0.7419000193476677},
#  {'id': 'cd0cfb77675741b68ed4086445228e92_5',
#   'prediction_text': 'our license examiner will give you an interim license that allows you to drive. ',
#   'no_answer_probability': 0.6538825035095215},
#  {'id': 'cd0cfb77675741b68ed4086445228e92_8',
#   'prediction_text': 'VISA Card ',
#   'no_answer_probability': 0.7523233443498611},
#  {'id': 'cd0cfb77675741b68ed4086445228e92_10',
#   'prediction_text': '\n\nyes or no survey: \n',
#   'no_answer_probability': 0.6946207284927368},
#  {'id': 'cd0cfb77675741b68ed4086445228e92_12',
#   'prediction_text': '',
#   'no_answer_probability': 0.6656851470470428},
#  {'id': '3f3aa224b819953746fd223c1e30eb73_1',
#   'prediction_text': ', ',
#   'no_answer_probability': 0.7427945137023926},
#  {'id': '3f3aa224b819953746fd223c1e30eb73_3',
#   'prediction_text': 'We welcome your suggestions for improving TVB services and operations. ',
#   'no_answer_probability': 0.7206296324729919},
#  {'id': '3f3aa224b819953746fd223c1e30eb73_6',
#   'prediction_text': 'Just as in traffic courts in other areas of the state , ',
#   'no_answer_probability': 0.7138710618019104},
#  {'id': '3f3aa224b819953746fd223c1e30eb73_8',
#   'prediction_text': 'On the following panel is a list of common violations and the number of points for each. LET US HEAR FROM YOU ',
#   'no_answer_probability': 0.7279492318630219},
#  {'id': '3f3aa224b819953746fd223c1e30eb73_10',
#   'prediction_text': 'Ask for more information at any motor vehicle office. ',
#   'no_answer_probability': 0.6793990433216095},
#  {'id': '3f3aa224b819953746fd223c1e30eb73_12',
#   'prediction_text': 'Read the instructions carefully. Remember to include a payment for the appeal fees. ',
#   'no_answer_probability': 0.8084851875901222},
#  {'id': '3f3aa224b819953746fd223c1e30eb73_14',
#   'prediction_text': 'you cannot plead by mail or online. ',
#   'no_answer_probability': 0.5636179149150848},
#  {'id': '3f3aa224b819953746fd223c1e30eb73_16',
#   'prediction_text': '\n\nINTRODUCTION \n',
#   'no_answer_probability': 0.7758590281009674},
#  {'id': '1ce198bc767426637a333a1adc62e37a_1',
#   'prediction_text': 'sign it , ',
#   'no_answer_probability': 0.7472319006919861},
#  {'id': '1ce198bc767426637a333a1adc62e37a_3',
#   'prediction_text': 'the ALJ will decide whether or not you are guilty. ',
#   'no_answer_probability': 0.7001258432865143},
#  {'id': '1ce198bc767426637a333a1adc62e37a_6',
#   'prediction_text': 'That decision will be based only on the evidence and testimony presented at the hearing and what the law states. ',
#   'no_answer_probability': 0.7782137840986252},
#  {'id': '1ce198bc767426637a333a1adc62e37a_8',
#   'prediction_text': "If you don't answer the ticket in the time allowed , ",
#   'no_answer_probability': 0.7144965529441833},
#  {'id': '1ce198bc767426637a333a1adc62e37a_10',
#   'prediction_text': 'Return to DMV Publications [5 ] ',
#   'no_answer_probability': 0.7356352508068085},
#  {'id': '1ce198bc767426637a333a1adc62e37a_12',
#   'prediction_text': 'Taking a DMV - approved accident prevention course can reduce your point total by up to four points and reduce your auto liability and collision insurance premiums by 10% for three years. ',
#   'no_answer_probability': 0.7199313044548035},
#  {'id': '9a45905f9c4bb1f095e1039dc0387be0_1',
#   'prediction_text': 'Change my existing NY State license / ID to a REAL ID or Enhanced \n\nStep 3: Go to the DMV \n',
#   'no_answer_probability': 0.7546986639499664},
#  {'id': '9a45905f9c4bb1f095e1039dc0387be0_4',
#   'prediction_text': 'Class B CDL ',
#   'no_answer_probability': 0.7933128178119659},
#  {'id': '9a45905f9c4bb1f095e1039dc0387be0_6',
#   'prediction_text': 'Application for Standard Permit, Driver License for Non - Driver ID Card PDF [2] MV-44 ',
#   'no_answer_probability': 0.6832712590694427},
#  {'id': '9a45905f9c4bb1f095e1039dc0387be0_8',
#   'prediction_text': 'If you plan to drive a taxi or livery vehicle in New York City , ',
#   'no_answer_probability': 0.7635527551174164},
#  {'id': '9a45905f9c4bb1f095e1039dc0387be0_10',
#   'prediction_text': '',
#   'no_answer_probability': 0.698476105928421},
#  {'id': '9a45905f9c4bb1f095e1039dc0387be0_12',
#   'prediction_text': 'surrender your Class D license. ',
#   'no_answer_probability': 0.8054661303758621},
#  {'id': '9a45905f9c4bb1f095e1039dc0387be0_14',
#   'prediction_text': 'you must be 18 years of age or older and you must have a driver license that is one of these classes ',
#   'no_answer_probability': 0.7631807625293732},
#  {'id': '07e9d1fe776f3431e82683047ee21968_1',
#   'prediction_text': 'take the vision test or prove that you meet our vision requirements [4 ] ',
#   'no_answer_probability': 0.7398416697978973},
#  {'id': '07e9d1fe776f3431e82683047ee21968_3',
#   'prediction_text': 'the fee depends on the expiration date of your current driver license - ',
#   'no_answer_probability': 0.7676997780799866},
#  {'id': '07e9d1fe776f3431e82683047ee21968_5',
#   'prediction_text': 'Class A commercial driver license CDL ',
#   'no_answer_probability': 0.7111997306346893},
#  {'id': '07e9d1fe776f3431e82683047ee21968_8',
#   'prediction_text': 'contact the Taxi and Limousine Commission [6]. ',
#   'no_answer_probability': 0.7463435530662537},
#  {'id': '07e9d1fe776f3431e82683047ee21968_10',
#   'prediction_text': '\n\nStep 2: Determine what identification you need to bring to the DMV \n',
#   'no_answer_probability': 0.6819559037685394},
#  {'id': '07e9d1fe776f3431e82683047ee21968_12',
#   'prediction_text': '\n\nStep 4: Get your Class E license in the mail \n',
#   'no_answer_probability': 0.7402723133563995},
#  {'id': '322b65fd61a560abefa6e48f7d6b4a22_1',
#   'prediction_text': '\n\nIs there a cost for this restriction? \n',
#   'no_answer_probability': 0.7764049172401428},
#  {'id': '322b65fd61a560abefa6e48f7d6b4a22_4',
#   'prediction_text': 'You are also subject to the problem driving restrictions. Yes. ',
#   'no_answer_probability': 0.8038925975561142},
#  {'id': '322b65fd61a560abefa6e48f7d6b4a22_6',
#   'prediction_text': '\n\nHow long will the restriction be in effect? Is there any way I can have the restriction removed early? \nIf your revocation was due to an alcohol - related incident , the restriction remains in effect for five years from the date you receive your driver license or permit. ',
#   'no_answer_probability': 0.7485284705956776},
#  {'id': '322b65fd61a560abefa6e48f7d6b4a22_8',
#   'prediction_text': "if the child's attendance at the school / day ",
#   'no_answer_probability': 0.7329483926296234},
#  {'id': '322b65fd61a560abefa6e48f7d6b4a22_10',
#   'prediction_text': 'You must carry the attachment whenever you operate a motor vehicle. ',
#   'no_answer_probability': 0.6640084683895111},
#  {'id': '322b65fd61a560abefa6e48f7d6b4a22_12',
#   'prediction_text': 'The problem driver restriction can only be applied to a class D license. ',
#   'no_answer_probability': 0.7833232879638672},
#  {'id': '23178e836c47051d9cc2be93932f6757_1',
#   'prediction_text': 'This includes a seat belt violation by the vehicle operator, but does not include parking, stopping, standing, equipment, inspection or other non - moving violations. ',
#   'no_answer_probability': 0.7449327111244202},
#  {'id': '23178e836c47051d9cc2be93932f6757_3',
#   'prediction_text': 'If your revocation was due to an alcohol - related incident , ',
#   'no_answer_probability': 0.772635817527771},
#  {'id': '23178e836c47051d9cc2be93932f6757_6',
#   'prediction_text': 'You can be issued a traffic ticket for driving out of restriction. ',
#   'no_answer_probability': 0.7646531313657761},
#  {'id': '23178e836c47051d9cc2be93932f6757_8',
#   'prediction_text': 'Yes. ',
#   'no_answer_probability': 0.6703527569770813},
#  {'id': '23178e836c47051d9cc2be93932f6757_10',
#   'prediction_text': 'visit the Ignition Interlock page [1] at the NYS Division of Criminal Justice Services website. ',
#   'no_answer_probability': 0.7792237997055054},
#  {'id': '23178e836c47051d9cc2be93932f6757_12',
#   'prediction_text': 'you can drive only ',
#   'no_answer_probability': 0.6207058131694794},
#  {'id': '5394941f2d884d14df83c54ed0fb57fd_1',
#   'prediction_text': '\n\nCan I transfer a title certificate that has a lien listed? \n',
#   'no_answer_probability': 0.7693605720996857},
#  {'id': '5394941f2d884d14df83c54ed0fb57fd_3',
#   'prediction_text': 'There are two acceptable proofs. ',
#   'no_answer_probability': 0.6608816981315613},
#  {'id': '5394941f2d884d14df83c54ed0fb57fd_5',
#   'prediction_text': 'When the new owner applies for a registration and title certificate , ',
#   'no_answer_probability': 0.7457021176815033},
#  {'id': '5394941f2d884d14df83c54ed0fb57fd_7',
#   'prediction_text': 'Send an Application for a Duplicate Certificate of Title PDF [2] MV-902 and the original proof that indicates that the lien is satisfied to the address above, or bring them to a DMV office. ',
#   'no_answer_probability': 0.6920964121818542},
#  {'id': '5394941f2d884d14df83c54ed0fb57fd_9',
#   'prediction_text': 'The title certificate must be mailed to you ; ',
#   'no_answer_probability': 0.6730967164039612},
#  {'id': '5394941f2d884d14df83c54ed0fb57fd_11',
#   'prediction_text': '\n\nDisable this transaction?: \n',
#   'no_answer_probability': 0.761108011007309},
#  {'id': '5394941f2d884d14df83c54ed0fb57fd_13',
#   'prediction_text': 'If you request that the DMV remove a lien when you apply for a duplicate title certificate , ',
#   'no_answer_probability': 0.6949991881847382},
#  {'id': '5394941f2d884d14df83c54ed0fb57fd_15',
#   'prediction_text': '\n\nyes or no survey: \n',
#   'no_answer_probability': 0.7361595034599304},
#  {'id': '79472ef27d72e53bfab6bec245039b05_1',
#   'prediction_text': '\n\nCommon Tasks: \n',
#   'no_answer_probability': 0.7976130247116089},
#  {'id': '79472ef27d72e53bfab6bec245039b05_3',
#   'prediction_text': 'The DMV will send you a NYS title certificate. ',
#   'no_answer_probability': 0.7491373121738434},
#  {'id': '79472ef27d72e53bfab6bec245039b05_5',
#   'prediction_text': '\n\nCan I transfer a title certificate that has a lien listed? \n',
#   'no_answer_probability': 0.7221451699733734},
#  {'id': '79472ef27d72e53bfab6bec245039b05_7',
#   'prediction_text': "If your lienholder has an account with the DMV's Electronic Lien Transfer system ELT , ",
#   'no_answer_probability': 0.8239684104919434},
#  {'id': '79472ef27d72e53bfab6bec245039b05_9',
#   'prediction_text': 'In many other states , ',
#   'no_answer_probability': 0.7694342136383057},
#  {'id': '79472ef27d72e53bfab6bec245039b05_11',
#   'prediction_text': 'The DMV processes a duplicate title certificate that does not list the lien and mails the certificate to you. ',
#   'no_answer_probability': 0.8483135998249054},
#  {'id': '79472ef27d72e53bfab6bec245039b05_13',
#   'prediction_text': 'NY 12228 - 0331 ',
#   'no_answer_probability': 0.7155944108963013},
#  {'id': 'ec9abdf1a9a455030e420a12b32fb693_1',
#   'prediction_text': '\n\nCommon Tasks: \n',
#   'no_answer_probability': 0.8194729685783386},
#  {'id': 'ec9abdf1a9a455030e420a12b32fb693_3',
#   'prediction_text': 'sales tax see sales tax information [2 ] If you transfer the registration and plates from another vehicle , you don t need to pay the plate fees or MCTD fee , ',
#   'no_answer_probability': 0.7855133761962255},
#  {'id': 'ec9abdf1a9a455030e420a12b32fb693_5',
#   'prediction_text': 'MCTD 1 fee for the following 12 counties only: Bronx, Kings Brooklyn, New York Manhattan, Queens, Richmond Staten Island, Dutchess, Nassau, Orange, Putnam, Rockland, Suffolk, and Westchester ',
#   'no_answer_probability': 0.7763828337192535},
#  {'id': 'ec9abdf1a9a455030e420a12b32fb693_7',
#   'prediction_text': '\n\nTopic: \n',
#   'no_answer_probability': 0.8539711534976959},
#  {'id': 'ec9abdf1a9a455030e420a12b32fb693_9',
#   'prediction_text': '\n\nShow "do it online" button in megamenu: \n',
#   'no_answer_probability': 0.8558702170848846},
#  {'id': 'ec9abdf1a9a455030e420a12b32fb693_11',
#   'prediction_text': 'You can also use these charts to estimate your registration fees, use taxes, and supplemental fees for ',
#   'no_answer_probability': 0.7708519250154495},
#  {'id': 'ec9abdf1a9a455030e420a12b32fb693_13',
#   'prediction_text': '\n\nEstimate fees and taxes online \nYou can also use these charts to estimate your registration fees, use taxes, and supplemental fees for commercial vehicles [4 ] Sorry , ',
#   'no_answer_probability': 0.8046884462237358},
#  {'id': 'b0a98aeaceb520c42eb42710df025ca1_1',
#   'prediction_text': 'you must have New York insurance coverage. ',
#   'no_answer_probability': 0.7477167844772339},
#  {'id': 'b0a98aeaceb520c42eb42710df025ca1_4',
#   'prediction_text': 'If you register your vehicle in another state and surrender the New York vehicle plates to the New York DMV , ',
#   'no_answer_probability': 0.6939477324485779},
#  {'id': 'b0a98aeaceb520c42eb42710df025ca1_6',
#   'prediction_text': 'No. ',
#   'no_answer_probability': 0.6792027354240417},
#  {'id': 'b0a98aeaceb520c42eb42710df025ca1_8',
#   'prediction_text': 'Please send us a copy of your out of state registration in your name along with a copy of your out of state insurance if available to : NYS Department of Motor Vehicles Financial Security Bureau PO BOX 2725 Albany NY 12220 - 0725 ',
#   'no_answer_probability': 0.7548450604081154},
#  {'id': 'b0a98aeaceb520c42eb42710df025ca1_10',
#   'prediction_text': 'No. \n\nCan I obtain out-of-state insurance and keep my vehicle registered in New York? \nNo. If you replace your New York State insurance coverage with out - of - state insurance , ',
#   'no_answer_probability': 0.8466088734567165},
#  {'id': 'ddce2ae456060c8c50cb8717afeaaec5_1',
#   'prediction_text': 'Most sponsors assign you a user ID and a password when you register for the course. ',
#   'no_answer_probability': 0.7648377567529678},
#  {'id': 'ddce2ae456060c8c50cb8717afeaaec5_3',
#   'prediction_text': 'Yes. ',
#   'no_answer_probability': 0.7095972299575806},
#  {'id': 'ddce2ae456060c8c50cb8717afeaaec5_5',
#   'prediction_text': 'This can include identity information like the DMV ID Number Client ID Number from your NY State driver license and your name and date of birth. ',
#   'no_answer_probability': 0.761456310749054},
#  {'id': 'ddce2ae456060c8c50cb8717afeaaec5_7',
#   'prediction_text': 'This can include identity information like the DMV ID Number Client ID Number from your NY State driver license and your name and date of birth. ',
#   'no_answer_probability': 0.7905818223953247},
#  {'id': 'ddce2ae456060c8c50cb8717afeaaec5_9',
#   'prediction_text': '\n\nWho offers the I-PIRP courses? \n',
#   'no_answer_probability': 0.6637689471244812},
#  {'id': 'ddce2ae456060c8c50cb8717afeaaec5_11',
#   'prediction_text': 'When you complete an I - PIRP course , ',
#   'no_answer_probability': 0.7441276907920837},
#  {'id': '072ed5e3eb9bef4f825ec06e96b64090_1',
#   'prediction_text': 'have been issued at least 6 months before you apply for a New York license unless it is commercial driver license that has been valid for any amount of time 2 ',
#   'no_answer_probability': 0.7343629002571106},
#  {'id': '072ed5e3eb9bef4f825ec06e96b64090_3',
#   'prediction_text': 'be valid or expired less than 24 months You cannot exchange your license if it is ',
#   'no_answer_probability': 0.6805898249149323},
#  {'id': '072ed5e3eb9bef4f825ec06e96b64090_5',
#   'prediction_text': 'a personal check or a money order payable to ',
#   'no_answer_probability': 0.7323374152183533},
#  {'id': '072ed5e3eb9bef4f825ec06e96b64090_7',
#   'prediction_text': 'For quicker service , ',
#   'no_answer_probability': 0.7985521405935287},
#  {'id': '072ed5e3eb9bef4f825ec06e96b64090_10',
#   'prediction_text': 'Your New York license will be valid for 5 years. ',
#   'no_answer_probability': 0.6777253746986389},
#  {'id': '479404020480fe8e05fd6bd1d4cdccab_1',
#   'prediction_text': 'do not submit an application with DMV yet! ',
#   'no_answer_probability': 0.6866750717163086},
#  {'id': '479404020480fe8e05fd6bd1d4cdccab_4',
#   'prediction_text': 'indicate that on your application. If you do not have your Surety Bond , ',
#   'no_answer_probability': 0.7494214624166489},
#  {'id': '479404020480fe8e05fd6bd1d4cdccab_6',
#   'prediction_text': '\n\nProof of Business Name \n',
#   'no_answer_probability': 0.7865070253610611},
#  {'id': '479404020480fe8e05fd6bd1d4cdccab_8',
#   'prediction_text': 'You will be contacted by a clerk from Vehicle Safety s Application Processing Unit. ',
# ...
#   'no_answer_probability': 0.7110344171524048},
#  {'id': '09183376ad5319c87d538c0f2481e510_14',
#   'prediction_text': '\n\nTransfer the of a vehicle (buy, sell, or give away) \n',
#   'no_answer_probability': 0.7577380836009979},
#  {'id': 'f99a36c314571dccd76c64aeb834f7f7_1',
#   'prediction_text': 'use your vehicle if your insurance coverage is cancelled , ',
#   'no_answer_probability': 0.7418583035469055},
#  {'id': 'f99a36c314571dccd76c64aeb834f7f7_5',
#   'prediction_text': 'or or ',
#   'no_answer_probability': 0.8537167757749557},
#  {'id': 'f99a36c314571dccd76c64aeb834f7f7_7',
#   'prediction_text': 'DMV must receive other acceptable proof ',
#   'no_answer_probability': 0.8191040754318237},
#  {'id': 'f99a36c314571dccd76c64aeb834f7f7_9',
#   'prediction_text': 'the registration and, if the lapse period is 91 days or more, your driver license will also be suspended for the same number of days. ',
#   'no_answer_probability': 0.712197870016098},
#  {'id': 'f99a36c314571dccd76c64aeb834f7f7_11',
#   'prediction_text': 'Therefore , ',
#   'no_answer_probability': 0.6461100876331329},
#  {'id': 'f99a36c314571dccd76c64aeb834f7f7_13',
#   'prediction_text': 'Read the letter or order see a sample [1] carefully, answer it quickly, and contact your insurance company immediately. ',
#   'no_answer_probability': 0.7278694808483124},
#  {'id': '1ce115e80931303c840d3e2d4fb470f2_1',
#   'prediction_text': 'the plates must be reported lost / stolen / confiscated , ',
#   'no_answer_probability': 0.7304286360740662},
#  {'id': '1ce115e80931303c840d3e2d4fb470f2_5',
#   'prediction_text': 'If you don t have insurance, or if it is about to expire and you don t plan to replace it , The letter means your insurance company notified the DMV that your insurance coverage ended, and that no other company notified the DMV about new coverage. ',
#   'no_answer_probability': 0.7042455077171326},
#  {'id': '1ce115e80931303c840d3e2d4fb470f2_7',
#   'prediction_text': 'even if you think it is a mistake ',
#   'no_answer_probability': 0.7001672983169556},
#  {'id': '1ce115e80931303c840d3e2d4fb470f2_9',
#   'prediction_text': 'If there is a problem , ',
#   'no_answer_probability': 0.8257734924554825},
#  {'id': '1ce115e80931303c840d3e2d4fb470f2_11',
#   'prediction_text': 'If you are not going to immediately replace your insurance coverage , ',
#   'no_answer_probability': 0.7264766991138458},
#  {'id': 'e6b627582fc81a9e6c8312c7f9cd14ef_1',
#   'prediction_text': 'If you have insurance , follow the instructions in the letter and contact your company or agent about the problem. If you don t have insurance , ',
#   'no_answer_probability': 0.7788802733023962},
#  {'id': 'e6b627582fc81a9e6c8312c7f9cd14ef_4',
#   'prediction_text': 'even if you think it is a mistake ',
#   'no_answer_probability': 0.8092908412218094},
#  {'id': 'e6b627582fc81a9e6c8312c7f9cd14ef_6',
#   'prediction_text': 'Therefore , ',
#   'no_answer_probability': 0.7272976636886597},
#  {'id': 'e6b627582fc81a9e6c8312c7f9cd14ef_8',
#   'prediction_text': 'Only your insurance company can file proof of insurance electronically. ',
#   'no_answer_probability': 0.7074943482875824},
#  {'id': 'e6b627582fc81a9e6c8312c7f9cd14ef_10',
#   'prediction_text': 'Paper proof or e - mail messages are NOT acceptable. ',
#   'no_answer_probability': 0.7313722372055054},
#  {'id': 'e6b627582fc81a9e6c8312c7f9cd14ef_12',
#   'prediction_text': 'even if you think it is a mistake ',
#   'no_answer_probability': 0.7707812488079071},
#  {'id': 'e6b627582fc81a9e6c8312c7f9cd14ef_14',
#   'prediction_text': 'The letter means your insurance company notified the DMV that your insurance coverage ended, and that no other company notified the DMV about new coverage. ',
#   'no_answer_probability': 0.7661713659763336},
#  {'id': '2f05a8c31b00c1db9cfdfd4b8c05d92a_1',
#   'prediction_text': 'you must surrender your plates. ',
#   'no_answer_probability': 0.6951975226402283},
#  {'id': '2f05a8c31b00c1db9cfdfd4b8c05d92a_4',
#   'prediction_text': 'If you don t have insurance , ',
#   'no_answer_probability': 0.791498526930809},
#  {'id': '2f05a8c31b00c1db9cfdfd4b8c05d92a_6',
#   'prediction_text': 'the registration must expire , ',
#   'no_answer_probability': 0.7263705730438232},
#  {'id': '2f05a8c31b00c1db9cfdfd4b8c05d92a_8',
#   'prediction_text': 'Read the letter or order see a sample [1] carefully, answer it quickly, and contact your insurance company immediately. ',
#   'no_answer_probability': 0.8143139183521271},
#  {'id': '2f05a8c31b00c1db9cfdfd4b8c05d92a_10',
#   'prediction_text': 'If you have insurance , ',
#   'no_answer_probability': 0.7856981456279755},
#  {'id': '2f05a8c31b00c1db9cfdfd4b8c05d92a_12',
#   'prediction_text': 'If you have insurance , ',
#   'no_answer_probability': 0.6564714908599854},
#  {'id': '05a65d539c40a37a9312b36ffa160507_1',
#   'prediction_text': 'prove that you have insurance coverage prove that you sold the vehicle ',
#   'no_answer_probability': 0.680339440703392},
#  {'id': '05a65d539c40a37a9312b36ffa160507_4',
#   'prediction_text': 'the registration and, if the lapse period is 91 days or more, your driver license will also be suspended for the same number of days. ',
#   'no_answer_probability': 0.7531120777130127},
#  {'id': '05a65d539c40a37a9312b36ffa160507_6',
#   'prediction_text': 'you need to surrender your vehicle plates to the DMV [2] immediately. ',
#   'no_answer_probability': 0.7520994991064072},
#  {'id': '05a65d539c40a37a9312b36ffa160507_8',
#   'prediction_text': 'Read the letter or order see a sample [1] carefully, answer it quickly, and contact your insurance company immediately. ',
#   'no_answer_probability': 0.722507894039154},
#  {'id': '05a65d539c40a37a9312b36ffa160507_10',
#   'prediction_text': 'Read the letter or order see a sample [1] carefully, answer it quickly, and contact your insurance company immediately. ',
#   'no_answer_probability': 0.7605119198560715},
#  {'id': '05a65d539c40a37a9312b36ffa160507_12',
#   'prediction_text': 'If there is a problem , ',
#   'no_answer_probability': 0.7422513067722321},
#  {'id': 'e07fd5a1725ffd8d9d9be8c871d8fbed_1',
#   'prediction_text': 'or ',
#   'no_answer_probability': 0.7616510093212128},
#  {'id': 'e07fd5a1725ffd8d9d9be8c871d8fbed_4',
#   'prediction_text': 'you need to surrender your vehicle plates to the DMV [2] immediately. ',
#   'no_answer_probability': 0.776187002658844},
#  {'id': 'e07fd5a1725ffd8d9d9be8c871d8fbed_6',
#   'prediction_text': 'the plates must be reported lost / stolen / confiscated , ',
#   'no_answer_probability': 0.745990127325058},
#  {'id': 'e07fd5a1725ffd8d9d9be8c871d8fbed_8',
#   'prediction_text': 'you need to surrender your vehicle plates to the DMV [2] immediately. ',
#   'no_answer_probability': 0.6948514580726624},
#  {'id': 'e07fd5a1725ffd8d9d9be8c871d8fbed_10',
#   'prediction_text': 'also ask your insurance company do not ask your agent or broker to file an electronic notice of insurance coverage with the DMV. ',
#   'no_answer_probability': 0.7835562825202942},
#  {'id': 'e07fd5a1725ffd8d9d9be8c871d8fbed_12',
#   'prediction_text': 'the plates must be surrendered , ',
#   'no_answer_probability': 0.7502260953187943},
#  {'id': 'e07fd5a1725ffd8d9d9be8c871d8fbed_14',
#   'prediction_text': 'If you do not , ',
#   'no_answer_probability': 0.76262366771698},
#  {'id': '7e14421a477a702dc9b7a42414a8fd16_1',
#   'prediction_text': '\n\nI received a Letter that states my insurance lapsed. What can I do? \n',
#   'no_answer_probability': 0.7777420282363892},
#  {'id': '7e14421a477a702dc9b7a42414a8fd16_4',
#   'prediction_text': 'or or ',
#   'no_answer_probability': 0.7154098898172379},
#  {'id': '7e14421a477a702dc9b7a42414a8fd16_6',
#   'prediction_text': 'you need to surrender your vehicle plates to the DMV [2] immediately. ',
#   'no_answer_probability': 0.7629881799221039},
#  {'id': '7e14421a477a702dc9b7a42414a8fd16_8',
#   'prediction_text': 'you need to surrender your vehicle plates to the DMV [2] immediately. If you have insurance , ',
#   'no_answer_probability': 0.7502891272306442},
#  {'id': '7e14421a477a702dc9b7a42414a8fd16_10',
#   'prediction_text': 'the plates must be surrendered , ',
#   'no_answer_probability': 0.7450786232948303},
#  {'id': '7e14421a477a702dc9b7a42414a8fd16_12',
#   'prediction_text': '\n\nI received a Letter that states my insurance lapsed. What can I do? \n',
#   'no_answer_probability': 0.8058987706899643},
#  {'id': '9a2fc3b0e7747cbeee0851275c44426c_1',
#   'prediction_text': '',
#   'no_answer_probability': 0.6849619448184967},
#  {'id': '9a2fc3b0e7747cbeee0851275c44426c_4',
#   'prediction_text': 'it is your responsibility to resolve it. even if you think it is a mistake ',
#   'no_answer_probability': 0.7932764738798141},
#  {'id': '9a2fc3b0e7747cbeee0851275c44426c_6',
#   'prediction_text': 'Therefore , ',
#   'no_answer_probability': 0.595328688621521},
#  {'id': '9a2fc3b0e7747cbeee0851275c44426c_8',
#   'prediction_text': '',
#   'no_answer_probability': 0.8083574771881104},
#  {'id': '9a2fc3b0e7747cbeee0851275c44426c_10',
#   'prediction_text': 'If you don t have insurance , ',
#   'no_answer_probability': 0.7304114997386932},
#  {'id': '9a2fc3b0e7747cbeee0851275c44426c_12',
#   'prediction_text': 'you need to surrender your vehicle registration and plates to the DMV immediately. ',
#   'no_answer_probability': 0.70992112159729},
#  {'id': '7bcec7013c27d261418177d1b2f6acb2_1',
#   'prediction_text': 'If there is a problem , ',
#   'no_answer_probability': 0.7598276287317276},
#  {'id': '7bcec7013c27d261418177d1b2f6acb2_3',
#   'prediction_text': 'Paper proof or e - mail messages are NOT acceptable. ',
#   'no_answer_probability': 0.7765252143144608},
#  {'id': '7bcec7013c27d261418177d1b2f6acb2_5',
#   'prediction_text': 'or ',
#   'no_answer_probability': 0.73604816198349},
#  {'id': '7bcec7013c27d261418177d1b2f6acb2_7',
#   'prediction_text': 'Only your insurance company can file proof of insurance electronically. ',
#   'no_answer_probability': 0.7684130817651749},
#  {'id': '7bcec7013c27d261418177d1b2f6acb2_9',
#   'prediction_text': 'If you don t have insurance , ',
#   'no_answer_probability': 0.815467357635498},
#  {'id': '7bcec7013c27d261418177d1b2f6acb2_11',
#   'prediction_text': 'the registration and, if the lapse period is 91 days or more, your driver license will also be suspended for the same number of days. ',
#   'no_answer_probability': 0.7058742642402649},
#  {'id': '7bcec7013c27d261418177d1b2f6acb2_13',
#   'prediction_text': 'Surrender your plates to the DMV. ',
#   'no_answer_probability': 0.7674085944890976},
#  {'id': '003d4710e450b70dd4e679e3949f2671_1',
#   'prediction_text': 'the DMV can suspend your vehicle registration and driver license. ',
#   'no_answer_probability': 0.785242110490799},
#  {'id': '003d4710e450b70dd4e679e3949f2671_3',
#   'prediction_text': 'the registration and, if the lapse period is 91 days or more, your driver license will also be suspended for the same number of days. ',
#   'no_answer_probability': 0.7762182652950287},
#  {'id': '003d4710e450b70dd4e679e3949f2671_5',
#   'prediction_text': 'the plates must be surrendered , the plates must be reported lost / stolen / confiscated , ',
#   'no_answer_probability': 0.7265388667583466},
#  {'id': '003d4710e450b70dd4e679e3949f2671_7',
#   'prediction_text': 'or ',
#   'no_answer_probability': 0.8412057310342789},
#  {'id': '003d4710e450b70dd4e679e3949f2671_9',
#   'prediction_text': 'you must surrender your plates. ',
#   'no_answer_probability': 0.7325905561447144},
#  {'id': '003d4710e450b70dd4e679e3949f2671_11',
#   'prediction_text': 'you may serve the suspension on the driver license first or you may serve the suspension on the registration first. ',
#   'no_answer_probability': 0.7188164591789246},
#  {'id': 'f9a4a78ccdc94c2f6f5b8f583153312b_1',
#   'prediction_text': 'If the registrant and registration class will not change , ',
#   'no_answer_probability': 0.7617280036211014},
#  {'id': 'f9a4a78ccdc94c2f6f5b8f583153312b_3',
#   'prediction_text': 'You must also pay a plate fee for the new plates , Contact the Custom Plates Unit at 1 - 518 - 402 - 4838. ',
#   'no_answer_probability': 0.8082341030240059},
#  {'id': 'f9a4a78ccdc94c2f6f5b8f583153312b_5',
#   'prediction_text': 'You will receive a receipt form FS-6 T when you surrender your personalized plates. ',
#   'no_answer_probability': 0.7204017639160156},
#  {'id': 'f9a4a78ccdc94c2f6f5b8f583153312b_7',
#   'prediction_text': 'Yes. ',
#   'no_answer_probability': 0.7871099710464478},
#  {'id': 'f9a4a78ccdc94c2f6f5b8f583153312b_9',
#   'prediction_text': 'Office hours are 8:00am - 4:00pm, Monday through Friday. ',
#   'no_answer_probability': 0.6089149713516235},
#  {'id': 'f9a4a78ccdc94c2f6f5b8f583153312b_11',
#   'prediction_text': 'The fees are $28.75 for passenger vehicle plates, and $18.75 for motorcycle plates. To replace your current personalized plates with new custom plates or personalized plates , ',
#   'no_answer_probability': 0.7366267889738083},
#  {'id': '8aa8cc7b7efd4fb75177c127a668e56b_1',
#   'prediction_text': 'your political party preference has changed \n\nHow do I know what my current voter registration status is? \n',
#   'no_answer_probability': 0.8031537085771561},
#  {'id': '8aa8cc7b7efd4fb75177c127a668e56b_3',
#   'prediction_text': '(Please allow up to six weeks to hear from the Board of Elections in your County. If after six weeks you have not heard from them, ',
#   'no_answer_probability': 0.6629069447517395},
#  {'id': '8aa8cc7b7efd4fb75177c127a668e56b_5',
#   'prediction_text': 'The DMV does not approve or deny voter registration applications. \n\nshow mydmv button in megamenu: \n',
#   'no_answer_probability': 0.8031274154782295},
#  {'id': '8aa8cc7b7efd4fb75177c127a668e56b_7',
#   'prediction_text': '\n\nShow "do it online" button in megamenu: \n',
#   'no_answer_probability': 0.7795153856277466},
#  {'id': '8aa8cc7b7efd4fb75177c127a668e56b_9',
#   'prediction_text': 'you must first correct this information before processing an online Voter Registration Application ',
#   'no_answer_probability': 0.740098237991333},
#  {'id': '8aa8cc7b7efd4fb75177c127a668e56b_11',
#   'prediction_text': 'your name has changed ',
#   'no_answer_probability': 0.8031103909015656},
#  {'id': '5d0e33436423051d41a2c526ce2d15cb_1',
#   'prediction_text': '\n\nIn general, when transferring ownership... \n',
#   'no_answer_probability': 0.8739742934703827},
#  {'id': '5d0e33436423051d41a2c526ce2d15cb_3',
#   'prediction_text': 'Proof of ownership is not available [10 ] [ 6]Register a snowmobile, boat or ATV [6 ] ',
#   'no_answer_probability': 0.803716205060482},
#  {'id': '5d0e33436423051d41a2c526ce2d15cb_5',
#   'prediction_text': '',
#   'no_answer_probability': 0.8178748041391373},
#  {'id': '5d0e33436423051d41a2c526ce2d15cb_7',
#   'prediction_text': 'You will need the Vehicle Identification Number VIN. ',
#   'no_answer_probability': 0.7164584994316101},
#  {'id': '5d0e33436423051d41a2c526ce2d15cb_9',
#   'prediction_text': 'Use DMV s Document Guide to make sure you get all documents you need from a seller so that you can register your vehicle in New York. ',
#   'no_answer_probability': 0.7757006585597992},
#  {'id': '5d0e33436423051d41a2c526ce2d15cb_11',
#   'prediction_text': 'You cannot change the name on the vehicle registration or the title certificate to the name of another person. \n\nTips for buying a vehicle \n',
#   'no_answer_probability': 0.7059494107961655},
#  {'id': '5d0e33436423051d41a2c526ce2d15cb_13',
#   'prediction_text': 'You must register the vehicle at a DMV office. ',
#   'no_answer_probability': 0.7789066731929779},
#  {'id': '51a8a0969480057016df43b16eac206f_1',
#   'prediction_text': 'the younger a person is , ',
#   'no_answer_probability': 0.6785553693771362},
#  {'id': '51a8a0969480057016df43b16eac206f_4',
#   'prediction_text': 'If your widow, widower, or surviving divorced spouse remarries after they reach age 60 age 50 if disabled , ',
#   'no_answer_probability': 0.6986023783683777},
#  {'id': '51a8a0969480057016df43b16eac206f_6',
#   'prediction_text': 'How much your family could receive in benefits ',
#   'no_answer_probability': 0.7000186443328857},
#  {'id': '51a8a0969480057016df43b16eac206f_8',
#   'prediction_text': 'How much your family could receive in benefits ',
#   'no_answer_probability': 0.6936242580413818},
#  ...]

# %%
import json

file = 'predictions_subtask1_cosine_simple.json'
with open(file, 'w') as outfile:
    json.dump(preds, outfile)
    
    
import os
cmd = 'python sharedtask_utils.py --task subtask1 --prediction_json '+file
os.system(cmd)
# Out:
# Reusing dataset doc2dial (/home/matt/.cache/huggingface/datasets/doc2dial/doc2dial_rc/1.0.1/cf6d3ed4e77cea477387dd51c171a021a09bd314cf3a2cb2a6431ca738c6c0ee)
# 2022-01-10 12:15:15.214499: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-10 12:15:15.214519: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# predictions_subtask1_cosine_simple.json
# {'exact': 0.8811681772406847, 'f1': 12.45214629361504, 'total': 3972, 'HasAns_exact': 0.8811681772406847, 'HasAns_f1': 12.45214629361504, 'HasAns_total': 3972, 'best_exact': 0.8811681772406847, 'best_exact_thresh': 0.8607330322265625, 'best_f1': 12.457181540342162, 'best_f1_thresh': 1.0079312324523926}
# 0

# %%
# good: {'exact': 0.9841443411700382, 'f1': 12.194171863834752, 'total': 1829, 'HasAns_exact': 0.9841443411700382, 'HasAns_f1': 12.194171863834752, 'HasAns_total': 1829, 'best_exact': 0.9841443411700382, 'best_exact_thresh': 0.9146314263343811, 'best_f1': 12.194171863834761, 'best_f1_thresh': 0.922089159488678}
# all:  {'exact': 1.2588116817724069, 'f1': 12.926781781634116, 'total': 3972, 'HasAns_exact': 1.2588116817724069, 'HasAns_f1': 12.926781781634116, 'HasAns_total': 3972, 'best_exact': 1.2588116817724069, 'best_exact_thresh': 0.8560804128646851, 'best_f1': 12.92678178163413, 'best_f1_thresh': 0.9933457970619202}
# all2: {'exact': 0.9566968781470292, 'f1': 12.527961387030402, 'total': 3972, 'HasAns_exact': 0.9566968781470292, 'HasAns_f1': 12.527961387030402, 'HasAns_total': 3972, 'best_exact': 0.9566968781470292, 'best_exact_thresh': 0.8959553837776184, 'best_f1': 12.527961387030405, 'best_f1_thresh': 0.9773053526878357}
